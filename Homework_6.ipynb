# %% [markdown]
# <a href="https://colab.research.google.com/github/Johana-collab/Homework-4/blob/main/Homework_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = "https://nutrition-calculator.p.rapidapi.com/api/bmi"

querystring = {"measurement_units":"std","feet":"5","inches":"4","lbs":"168"}

headers = {
	"x-rapidapi-key": "8e676001e4msh574f6779df31001p19bb82jsn648ed3209a0d",
	"x-rapidapi-host": "nutrition-calculator.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'bmi': '28.834'}

# %%
import requests

url = "https://rottentomato.p.rapidapi.com/"

querystring = {"name":"Tangerines"}

headers = {
	"x-rapidapi-key": "8e676001e4msh574f6779df31001p19bb82jsn648ed3209a0d",
	"x-rapidapi-host": "rottentomato.p.rapidapi.com",
	"Content-Type": "json"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'audience_score': None, 'critic_reviews': [], 'critics_consensus': "Critics Consensus\n        \nTangerines' impassioned message and the strong work of a solid cast more than make up for the movie's flawed narrative and uneven structure.\nRead Critics Reviews", 'image': 'https://resizing.flixster.com/KQyCNegKaeV-v9C_AV2y1UaYEcY=/1024x1024/v2/https://resizing.flixster.com/-XZAfHZM39UwaGJIFWKAE8fS0ak=/v3/t/assets/p10750064_p_v8_aa.jpg', 'title': 'Tangerines', 'tomatometer_score': None}

# %%
from pprint import pprint
pprint (response.json())
# Out:
# {'audience_score': None,
#  'critic_reviews': [],
#  'critics_consensus': 'Critics Consensus\n'
#                       '        \n'
#                       "Tangerines' impassioned message and the strong work of "
#                       "a solid cast more than make up for the movie's flawed "
#                       'narrative and uneven structure.\n'
#                       'Read Critics Reviews',
#  'image': 'https://resizing.flixster.com/KQyCNegKaeV-v9C_AV2y1UaYEcY=/1024x1024/v2/https://resizing.flixster.com/-XZAfHZM39UwaGJIFWKAE8fS0ak=/v3/t/assets/p10750064_p_v8_aa.jpg',
#  'title': 'Tangerines',
#  'tomatometer_score': None}

# %%
import requests

url = "https://shazam.p.rapidapi.com/v2/auto-complete"

querystring = {"term":"MORNING"}

headers = {
	"x-rapidapi-key": "8e676001e4msh574f6779df31001p19bb82jsn648ed3209a0d",
	"x-rapidapi-host": "shazam.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'results': {'terms': ['morning', 'morning playlist', 'morning chill']}, 'meta': {'metrics': {'dataSetId': '23e5d417-a910-45ec-b4c2-ecea65272371'}}}

# %%
from pprint import pprint
pprint (response.json())
# Out:
# {'meta': {'metrics': {'dataSetId': '23e5d417-a910-45ec-b4c2-ecea65272371'}},
#  'results': {'terms': ['morning', 'morning playlist', 'morning chill']}}

# %%
import requests

url = "https://google-translate-v21.p.rapidapi.com/translate_multi"

payload = {
	"texte": ["Have a wonderful weekend "],
	"to": "es"
}
headers = {
	"x-rapidapi-key": "8e676001e4msh574f6779df31001p19bb82jsn648ed3209a0d",
	"x-rapidapi-host": "google-translate-v21.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

print(response.json())
# Out:
# {'translations': [{'text': 'Que tengas un maravilloso fin de semana.', 'translation_info': '🇬🇧 English ➜ 🇪🇸 Spanish'}]}

# %%
from pprint import pprint
pprint (response.json())
# Out:
# {'translations': [{'text': 'Que tengas un maravilloso fin de semana.',
#                    'translation_info': '🇬🇧 English ➜ 🇪🇸 Spanish'}]}
